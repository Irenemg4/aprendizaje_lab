# %% [markdown]
# ### *100495718 Alicia Sáenz de Zaítigui*
# ### *100495931 Irene Muñoz*

# %% [markdown]
# # PRÁCTICA 1 APRENDIZAJE AUTOMÁTICO: EDA

# %% [markdown]
# Para comenzar, importamos la biblioteca pandas para leer los datos y poder comenzar el análisis.

# %%
import pandas as pd

# Leer el archivo CSV
datos = pd.read_csv('attrition_availabledata_09.csv')

datos
# Out:
#            hrs  absences  JobInvolvement  PerformanceRating  \
# 0     7.434015         8               3                  3
# 1     6.572103        15               4                  3
# 2     8.075888         4               3                  3
# 3     8.694279         6               3                  3
# 4     6.646379         9               3                  4
# ...        ...       ...             ...                ...
# 2935  5.622518        16               2                  4
# 2936  9.553096         4               3                  3
# 2937  6.734752        19               1                  3
# 2938  8.035525        14               2                  3
# 2939  6.524198        21               4                  3
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  Age  \
# 0                         4.0              2.0              3.0   25
# 1                         3.0              3.0              3.0   18
# ...
